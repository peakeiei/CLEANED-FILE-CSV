# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\DSI\Desktop\DSI ปี 3 เทอม 2\DSI323 Yim\งาน\assignment_c.csv')

# %%
df.head()
# Out:
#   เป็นโรงงานหรืออาคาร ประเภทโรงงานอาคาร รหัสควบคุม  ปริมาณการใช้ไฟฟ้า (MJ)
# 0              โรงงาน            กระดาษ     3E8F16              11143440.0  \
# 1              โรงงาน            กระดาษ     4014DB               8259516.0
# 2              โรงงาน            กระดาษ     401560              32180400.0
# 3              โรงงาน            กระดาษ     401617              28413936.0
# 4              โรงงาน            กระดาษ     419870              18147600.0
#
#    รวมปริมาณพลังงานความร้อน (MJ)   รวมพลังงานทั้งหมด (MJ)
# 0                      1521366.24             1.266481e+07  \
# 1                            0.00             8.259516e+06
# 2                            0.00             3.218040e+07
# 3                     77009680.00             1.054236e+08
# 4                     63812730.00             8.196033e+07
#
#    ผลการประหยัดไฟฟ้าจริง (MJ)   ผลการประหยัดพลังงานความร้อนจริง (MJ)
# 0                   232732.620                              243370.38  \
# ...

# %%
df.columns
# Out:
# Index(['เป็นโรงงานหรืออาคาร', 'ประเภทโรงงานอาคาร', 'รหัสควบคุม',
#        'ปริมาณการใช้ไฟฟ้า (MJ)', 'รวมปริมาณพลังงานความร้อน (MJ) ',
#        'รวมพลังงานทั้งหมด (MJ) ', 'ผลการประหยัดไฟฟ้าจริง (MJ) ',
#        'ผลการประหยัดพลังงานความร้อนจริง (MJ) ',
#        'ผลการประหยัดพลังงานรวม (MJ) '],
#       dtype='object')

# %%
df.isnull()
# Out:
#       เป็นโรงงานหรืออาคาร  ประเภทโรงงานอาคาร  รหัสควบคุม
# 0                   False              False       False  \
# 1                   False              False       False
# 2                   False              False       False
# 3                   False              False       False
# 4                   False              False       False
# ...                   ...                ...         ...
# 6724                False              False       False
# 6725                False              False       False
# 6726                False              False       False
# 6727                False              False       False
# 6728                False              False       False
#
#       ปริมาณการใช้ไฟฟ้า (MJ)  รวมปริมาณพลังงานความร้อน (MJ)
# 0                      False                           False  \
# 1                      False                           False
# 2                      False                           False
# ...

# %%
# check ว่าช่องไหนมี null
df.isnull().any()
# Out:
# เป็นโรงงานหรืออาคาร                      False
# ประเภทโรงงานอาคาร                        False
# รหัสควบคุม                               False
# ปริมาณการใช้ไฟฟ้า (MJ)                    True
# รวมปริมาณพลังงานความร้อน (MJ)            False
# รวมพลังงานทั้งหมด (MJ)                   False
# ผลการประหยัดไฟฟ้าจริง (MJ)                True
# ผลการประหยัดพลังงานความร้อนจริง (MJ)      True
# ผลการประหยัดพลังงานรวม (MJ)              False
# dtype: bool

# %%
# check จำนวน null
df.isnull().sum()
# Out:
# เป็นโรงงานหรืออาคาร                         0
# ประเภทโรงงานอาคาร                           0
# รหัสควบคุม                                  0
# ปริมาณการใช้ไฟฟ้า (MJ)                    477
# รวมปริมาณพลังงานความร้อน (MJ)               0
# รวมพลังงานทั้งหมด (MJ)                      0
# ผลการประหยัดไฟฟ้าจริง (MJ)               1093
# ผลการประหยัดพลังงานความร้อนจริง (MJ)     5766
# ผลการประหยัดพลังงานรวม (MJ)                 0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 7336

# %%
df.head()
# Out:
#   เป็นโรงงานหรืออาคาร ประเภทโรงงานอาคาร รหัสควบคุม  ปริมาณการใช้ไฟฟ้า (MJ)
# 0              โรงงาน            กระดาษ     3E8F16              11143440.0  \
# 1              โรงงาน            กระดาษ     4014DB               8259516.0
# 2              โรงงาน            กระดาษ     401560              32180400.0
# 3              โรงงาน            กระดาษ     401617              28413936.0
# 4              โรงงาน            กระดาษ     419870              18147600.0
#
#    รวมปริมาณพลังงานความร้อน (MJ)   รวมพลังงานทั้งหมด (MJ)
# 0                      1521366.24             1.266481e+07  \
# 1                            0.00             8.259516e+06
# 2                            0.00             3.218040e+07
# 3                     77009680.00             1.054236e+08
# 4                     63812730.00             8.196033e+07
#
#    ผลการประหยัดไฟฟ้าจริง (MJ)   ผลการประหยัดพลังงานความร้อนจริง (MJ)
# 0                   232732.620                              243370.38  \
# ...

# %%
# สร้างตัวแปรเก็บค่า
df = df.fillna(0)

# %%
df.head()
# Out:
#   เป็นโรงงานหรืออาคาร ประเภทโรงงานอาคาร รหัสควบคุม  ปริมาณการใช้ไฟฟ้า (MJ)
# 0              โรงงาน            กระดาษ     3E8F16              11143440.0  \
# 1              โรงงาน            กระดาษ     4014DB               8259516.0
# 2              โรงงาน            กระดาษ     401560              32180400.0
# 3              โรงงาน            กระดาษ     401617              28413936.0
# 4              โรงงาน            กระดาษ     419870              18147600.0
#
#    รวมปริมาณพลังงานความร้อน (MJ)   รวมพลังงานทั้งหมด (MJ)
# 0                      1521366.24             1.266481e+07  \
# 1                            0.00             8.259516e+06
# 2                            0.00             3.218040e+07
# 3                     77009680.00             1.054236e+08
# 4                     63812730.00             8.196033e+07
#
#    ผลการประหยัดไฟฟ้าจริง (MJ)   ผลการประหยัดพลังงานความร้อนจริง (MJ)
# 0                   232732.620                              243370.38  \
# ...

# %%
# Export the cleaned DataFrame to a new CSV file
df.to_csv('05.csv', index=False, encoding='utf-8-sig')
